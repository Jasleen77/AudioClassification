# %%
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa
import librosa.display
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\asus\\Documents\\NIELIT\\AudioClassification'

# %% [markdown]
# ## MODEL TRAINING..

# %%
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa
import librosa.display


# %matplotlib inline

# %%
plt.figure(figsize=(15,7))

# %%
#Loading the file...
import os
file_name=r"TestAudios\sample1.wav"
filename = os.path.join(os.getcwd(),file_name)
# filename =r"C:\Users\asus\Downloads\audio\sample.wav"
os.path.exists(filename)
LibData,sr=librosa.load(filename)
#We got sample rate and data after loading.

librosa.display.waveplot(LibData,sr=sr)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr
# Out:
# 22050

# %%
#22050 is normalised due to librosa..
#scipy has other sample rate/s.i.e. 44KHZ
from scipy.io import wavfile as wav
sr2,AudioDataSci,=wav.read(filename)
sr2
# Out:
# 48000

# %%
AudioDataSci
# this is our signal in form of array..
# Out:
# array([-535, -494, -371, ...,  340,  844, 1216], dtype=int16)

# %%
LibData
#Lib data is normalised...
# Out:
# array([-0.01167726, -0.01236643, -0.00319345, ..., -0.01441306,
#         0.00390815,  0.        ], dtype=float32)

# %% [markdown]
# ### Read Metadata File

# %%
metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(10)
#displaying first ten records.
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# ...

# %%
metadata['class'].value_counts()
#Checking that dataset balanced or not.
# Out:
# dog_bark            1000
# air_conditioner     1000
# street_music        1000
# drilling            1000
# engine_idling       1000
# jackhammer          1000
# children_playing    1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %%
metadata.isnull().sum()
# Out:
# slice_file_name    0
# fsID               0
# start              0
# end                0
# salience           0
# fold               0
# classID            0
# class              0
# dtype: int64

# %% [markdown]
# ## DATA PREPROCESSING...

# %%
import librosa
AudioFilePath='Testaudios/7965-3-22-0.wav'
AudioData,AudioSampleRate=librosa.load(AudioFilePath)
print(AudioData)
import matplotlib.pyplot as plt
plt.figure(figsize=(2,20))
print(AudioData)
# Out:
# [ 0.          0.          0.         ... -0.02891508 -0.03861919
#   0.        ]
# [ 0.          0.          0.         ... -0.02891508 -0.03861919
#   0.        ]

# %%
plt.plot(AudioData)

# %%
from scipy.io import wavfile as wav
WaveSampleRate,WaveAudioData=wav.read(AudioFilePath)

# %%
WaveSampleRate
# Out:
# 44100

# %%
WaveAudioData
# Out:
# array([[    0,     0],
#        [    0,     0],
#        [    0,     0],
#        ...,
#        [-1384,  -278],
#        [-1089, -2036],
#        [ -937,   259]], dtype=int16)
